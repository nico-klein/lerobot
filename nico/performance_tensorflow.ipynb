# %%
import sys, io
import datetime
import tensorflow as tf

print('python:     ', sys.version.replace('\n', ' '))
print('keras :     ', tf.keras.__version__)
print('tensorflow: ', tf.__version__)
# Out:
# python:      3.10.11 (v3.10.11:7d4cc5aa85, Apr  4 2023, 19:05:19) [Clang 13.0.0 (clang-1300.0.29.30)]
# keras :      3.9.2
# tensorflow:  2.16.2

# %%
# imac intel        : 1h 13 min  (3.10.11 , keras 3.9.2, tensorflow 2.16.2)
# colab normal      : 4h 23 Min  (3.11.12 , keras 3.8.0, tensorflow 2.18.0.)
# colab T4          : 0h 05 Min  (3.11.12 , keras 3.8.0, tensorflow 2.18.0.)
# macbook air m3    : 1h 44min

# %%
cifar = tf.keras.datasets.cifar100
(x_train, y_train), (x_test, y_test) = cifar.load_data()

start_time = datetime.datetime.now()
model = tf.keras.applications.ResNet50(
    include_top=True,
    weights=None,
    input_shape=(x_train.shape[1], x_train.shape[2], x_train.shape[3]),
    classes=100,)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
model.compile(optimizer="adam", loss=loss_fn, metrics=["accuracy"])
model.fit(x_train, y_train, epochs=5, batch_size=64)

end_time = datetime.datetime.now()
print(f"time {end_time - start_time}")
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 923s 1s/step - accuracy: 0.0521 - loss: 5.0935
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 924s 1s/step - accuracy: 0.0873 - loss: 4.4060
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 977s 1s/step - accuracy: 0.1358 - loss: 3.9763
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 943s 1s/step - accuracy: 0.1663 - loss: 3.7924
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 919s 1s/step - accuracy: 0.2131 - loss: 3.4226
# time 1:18:07.494611
