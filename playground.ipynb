# %%
import platform
import sys

# %%
print(platform.system())
print(platform.machine())
print(sys.executable)
# Out:
# Darwin
# x86_64
# /Users/A301947/projects/venv/lerobot/bin/python3

# %%
if platform.system() == "Darwin":
    if platform.machine() == "x86_64":
        print("Intel Mac.")
    else:
        print("Arm Mac.")
elif platform.system() == "Linux":
    print("Linux")
else:
    print("unknown OS")
# Out:
# Intel Mac.
